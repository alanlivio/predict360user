# %%
import sys
import os
import numpy as np
import pandas as pd
from Utils import eulerian_to_cartesian, cartesian_to_eulerian, rotationBetweenVectors, interpolate_quaternions, degrees_to_radian, radian_to_degrees, compute_orthodromic_distance, store_dict_as_csv
from pyquaternion import Quaternion
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import cv2
import argparse
import head_motion_prediction.Utils
from head_motion_prediction.David_MMSys_18.Read_Dataset import *
# original_dataset = get_original_dataset()
project_path = "head_motion_prediction"
if os.path.basename(os.getcwd()) != project_path:
    print("moving to {project_patzh}")   
    os.chdir(project_path)
    sampled_dataset = load_sampled_dataset()

# %%
# print(sampled_dataset['0']['10_Cows'])
user='0'
video='10_Cows'
plot_3d_trace(sampled_dataset[user][video][:, 1:], user, video)
